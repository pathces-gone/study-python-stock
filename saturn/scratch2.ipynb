# %%
# !pip3 install --user git+https://github.com/quantopian/pyfolio
# !pip3 install --user finance-datareader

# %%
import warnings
warnings.filterwarnings(action='ignore') #default
import FinanceDataReader as fdr
import pyfolio as pf

# %%
from pykrx import stock
import pandas as pd

df = stock.get_market_ohlcv('2020-01-03','2022-01-03', '005930')
df = df['종가'].pct_change().fillna(0)

# %%
pf.create_returns_tear_sheet(df)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2020-01-03</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2022-01-03</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>23</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>19.339%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>41.622%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>28.165%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.77</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.61</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.60</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-31.891%</td>
#     </tr>
#     <tr>
# ...
